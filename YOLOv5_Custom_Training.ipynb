# %% [markdown]
# <a href="https://colab.research.google.com/github/CakeNuthep/YOLOv5-Custom-Training/blob/main/YOLOv5_Custom_Training.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Custom Training with YOLOv5
#
# In this tutorial, we assemble a dataset and train a custom YOLOv5 model to recognize the objects in our dataset. To do so we will take the following steps:
#
# * Gather a dataset of images and label our dataset
# * Export our dataset to YOLOv5
# * Train YOLOv5 to recognize the objects in our dataset
# * Evaluate our YOLOv5 model's performance
# * Run test inference to view our model at work
#
#
#
# ![](https://uploads-ssl.webflow.com/5f6bc60e665f54545a1e52a5/615627e5824c9c6195abfda9_computer-vision-cycle.png)

# %% [markdown]
# # Step 1: Install Requirements

# %%
#clone YOLOv5 and 
# !git clone https://github.com/ultralytics/yolov5  # clone repo
# %cd yolov5
# %pip install -qr requirements.txt # install dependencies
# %pip install -q roboflow

import torch
import os
from IPython.display import Image, clear_output  # to display images

print(f"Setup complete. Using torch {torch.__version__} ({torch.cuda.get_device_properties(0).name if torch.cuda.is_available() else 'CPU'})")
# Out:
# fatal: destination path 'yolov5' already exists and is not an empty directory.
# /content/yolov5
# Setup complete. Using torch 1.12.1+cu113 (Tesla T4)

# %% [markdown]
# # Step 2: Assemble Our Dataset
#
# In order to train our custom model, we need to assemble a dataset of representative images with bounding box annotations around the objects that we want to detect. And we need our dataset to be in YOLOv5 format.
#
# In Roboflow, you can choose between two paths:
#
# * Convert an existing dataset to YOLOv5 format. Roboflow supports over [30 formats object detection formats](https://roboflow.com/formats) for conversion.
# * Upload raw images and annotate them in Roboflow with [Roboflow Annotate](https://docs.roboflow.com/annotate).
#
# # Annotate
#
# ![](https://roboflow-darknet.s3.us-east-2.amazonaws.com/roboflow-annotate.gif)
#
# # Version
#
# ![](https://roboflow-darknet.s3.us-east-2.amazonaws.com/robolfow-preprocessing.png)

# %%
from roboflow import Roboflow
rf = Roboflow(model_format="yolov5", notebook="ultralytics")
# Out:
# upload and label your dataset, and get an API KEY here: https://app.roboflow.com/?model=yolov5&ref=ultralytics

# %%
# set up environment
os.environ["DATASET_DIRECTORY"] = "/content/datasets"

# %%
#after following the link above, recieve python code with these fields filled in
#from roboflow import Roboflow
#rf = Roboflow(api_key="YOUR API KEY HERE")
#project = rf.workspace().project("YOUR PROJECT")
#dataset = project.version("YOUR VERSION").download("yolov5")
rf = Roboflow(api_key="Sgt30gmp9ckCnL9OgNjF")
project = rf.workspace("home-wfoph").project("hard-hat-sample-8vcd1")
dataset = project.version(3).download("yolov5")
# Out:
# loading Roboflow workspace...
# loading Roboflow project...
# Downloading Dataset Version Zip in /content/datasets/Hard-Hat-Sample-3 to yolov5pytorch: 100% [3310332 / 3310332] bytes
# Extracting Dataset Version Zip to /content/datasets/Hard-Hat-Sample-3 in yolov5pytorch:: 100%|██████████| 211/211 [00:00<00:00, 1667.45it/s]

# %% [markdown]
# # Step 3: Train Our Custom YOLOv5 model
#
# Here, we are able to pass a number of arguments:
# - **img:** define input image size
# - **batch:** determine batch size
# - **epochs:** define the number of training epochs. (Note: often, 3000+ are common here!)
# - **data:** Our dataset locaiton is saved in the `dataset.location`
# - **weights:** specify a path to weights to start transfer learning from. Here we choose the generic COCO pretrained checkpoint.
# - **cache:** cache images for faster training

# %%
{dataset.location}
# Out:
# {'/content/datasets/Hard-Hat-Sample-3'}

# %%
# !python train.py --img 416 --batch 16 --epochs 150 --data {dataset.location}/data.yaml --weights yolov5s.pt --cache
# Out:
# train: weights=yolov5s.pt, cfg=, data=/content/datasets/Hard-Hat-Sample-3/data.yaml, hyp=data/hyps/hyp.scratch-low.yaml, epochs=150, batch_size=16, imgsz=416, rect=False, resume=False, nosave=False, noval=False, noautoanchor=False, noplots=False, evolve=None, bucket=, cache=ram, image_weights=False, device=, multi_scale=False, single_cls=False, optimizer=SGD, sync_bn=False, workers=8, project=runs/train, name=exp, exist_ok=False, quad=False, cos_lr=False, label_smoothing=0.0, patience=100, freeze=[0], save_period=-1, seed=0, local_rank=-1, entity=None, upload_dataset=False, bbox_interval=-1, artifact_alias=latest
# github: up to date with https://github.com/ultralytics/yolov5 ✅
# YOLOv5 🚀 v6.2-61-gffbce38 Python-3.7.13 torch-1.12.1+cu113 CUDA:0 (Tesla T4, 15110MiB)
#
# hyperparameters: lr0=0.01, lrf=0.01, momentum=0.937, weight_decay=0.0005, warmup_epochs=3.0, warmup_momentum=0.8, warmup_bias_lr=0.1, box=0.05, cls=0.5, cls_pw=1.0, obj=1.0, obj_pw=1.0, iou_t=0.2, anchor_t=4.0, fl_gamma=0.0, hsv_h=0.015, hsv_s=0.7, hsv_v=0.4, degrees=0.0, translate=0.1, scale=0.5, shear=0.0, perspective=0.0, flipud=0.0, fliplr=0.5, mosaic=1.0, mixup=0.0, copy_paste=0.0
# Weights & Biases: run 'pip install wandb' to automatically track and visualize YOLOv5 🚀 runs in Weights & Biases
# ClearML: run 'pip install clearml' to automatically track, visualize and remotely train YOLOv5 🚀 in ClearML
# TensorBoard: Start with 'tensorboard --logdir runs/train', view at http://localhost:6006/
# Overriding model.yaml nc=80 with nc=3
#
#                  from  n    params  module                                  arguments
#   0                -1  1      3520  models.common.Conv                      [3, 32, 6, 2, 2]
#   1                -1  1     18560  models.common.Conv                      [32, 64, 3, 2]
#   2                -1  1     18816  models.common.C3                        [64, 64, 1]
#   3                -1  1     73984  models.common.Conv                      [64, 128, 3, 2]
#   4                -1  2    115712  models.common.C3                        [128, 128, 2]
#   5                -1  1    295424  models.common.Conv                      [128, 256, 3, 2]
#   6                -1  3    625152  models.common.C3                        [256, 256, 3]
#   7                -1  1   1180672  models.common.Conv                      [256, 512, 3, 2]
#   8                -1  1   1182720  models.common.C3                        [512, 512, 1]
#   9                -1  1    656896  models.common.SPPF                      [512, 512, 5]
#  10                -1  1    131584  models.common.Conv                      [512, 256, 1, 1]
#  11                -1  1         0  torch.nn.modules.upsampling.Upsample    [None, 2, 'nearest']
#  12           [-1, 6]  1         0  models.common.Concat                    [1]
#  13                -1  1    361984  models.common.C3                        [512, 256, 1, False]
#  14                -1  1     33024  models.common.Conv                      [256, 128, 1, 1]
#  15                -1  1         0  torch.nn.modules.upsampling.Upsample    [None, 2, 'nearest']
#  16           [-1, 4]  1         0  models.common.Concat                    [1]
#  17                -1  1     90880  models.common.C3                        [256, 128, 1, False]
#  18                -1  1    147712  models.common.Conv                      [128, 128, 3, 2]
#  19          [-1, 14]  1         0  models.common.Concat                    [1]
#  20                -1  1    296448  models.common.C3                        [256, 256, 1, False]
#  21                -1  1    590336  models.common.Conv                      [256, 256, 3, 2]
#  22          [-1, 10]  1         0  models.common.Concat                    [1]
#  23                -1  1   1182720  models.common.C3                        [512, 512, 1, False]
#  24      [17, 20, 23]  1     21576  models.yolo.Detect                      [3, [[10, 13, 16, 30, 33, 23], [30, 61, 62, 45, 59, 119], [116, 90, 156, 198, 373, 326]], [128, 256, 512]]
# Model summary: 270 layers, 7027720 parameters, 7027720 gradients, 16.0 GFLOPs
#
# Transferred 343/349 items from yolov5s.pt
# AMP: checks passed ✅
# optimizer: SGD(lr=0.01) with parameter groups 57 weight(decay=0.0), 60 weight(decay=0.0005), 60 bias
# albumentations: Blur(p=0.01, blur_limit=(3, 7)), MedianBlur(p=0.01, blur_limit=(3, 7)), ToGray(p=0.01), CLAHE(p=0.01, clip_limit=(1, 4.0), tile_grid_size=(8, 8))
# train: Scanning '/content/datasets/Hard-Hat-Sample-3/train/labels' images and labels...70 found, 0 missing, 0 empty, 0 corrupt: 100% 70/70 [00:00<00:00, 2016.63it/s]
# train: New cache created: /content/datasets/Hard-Hat-Sample-3/train/labels.cache
# train: Caching images (0.0GB ram): 100% 70/70 [00:00<00:00, 376.78it/s]
# val: Scanning '/content/datasets/Hard-Hat-Sample-3/valid/labels' images and labels...20 found, 0 missing, 0 empty, 0 corrupt: 100% 20/20 [00:00<00:00, 701.02it/s]
# val: New cache created: /content/datasets/Hard-Hat-Sample-3/valid/labels.cache
# val: Caching images (0.0GB ram): 100% 20/20 [00:00<00:00, 129.53it/s]
#
# AutoAnchor: 4.87 anchors/target, 1.000 Best Possible Recall (BPR). Current anchors are a good fit to dataset ✅
# Plotting labels to runs/train/exp2/labels.jpg...
# Image sizes 416 train, 416 val
# Using 2 dataloader workers
# Logging results to runs/train/exp2
# Starting training for 150 epochs...
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       0/149      1.74G     0.1196    0.05279    0.04099         61        416: 100% 5/5 [00:03<00:00,  1.44it/s]
#                  Class     Images  Instances          P          R     mAP@.5 mAP@.5:.95: 100% 1/1 [00:00<00:00,  2.99it/s]
#                    all         20        125     0.0018     0.0763    0.00293    0.00086
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       1/149      1.84G     0.1159    0.05107    0.04058         51        416: 100% 5/5 [00:01<00:00,  4.68it/s]
#                  Class     Images  Instances          P          R     mAP@.5 mAP@.5:.95: 100% 1/1 [00:00<00:00,  3.87it/s]
#                    all         20        125    0.00285      0.116    0.00279   0.000755
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       2/149      1.84G     0.1125    0.06024    0.03919         64        416: 100% 5/5 [00:00<00:00,  5.17it/s]
#                  Class     Images  Instances          P          R     mAP@.5 mAP@.5:.95: 100% 1/1 [00:00<00:00,  3.98it/s]
#                    all         20        125      0.006      0.238    0.00571    0.00133
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       3/149      1.84G     0.1064    0.05944    0.03715         66        416: 100% 5/5 [00:00<00:00,  5.54it/s]
#                  Class     Images  Instances          P          R     mAP@.5 mAP@.5:.95: 100% 1/1 [00:00<00:00,  4.27it/s]
#                    all         20        125    0.00808      0.347     0.0108    0.00261
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       4/149      1.84G     0.1023     0.0662    0.03606         45        416: 100% 5/5 [00:00<00:00,  5.26it/s]
#                  Class     Images  Instances          P          R     mAP@.5 mAP@.5:.95: 100% 1/1 [00:00<00:00,  4.61it/s]
#                    all         20        125    0.00964      0.443      0.031    0.00828
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       5/149      1.84G    0.09718    0.06779    0.03428         56        416: 100% 5/5 [00:00<00:00,  5.81it/s]
#                  Class     Images  Instances          P          R     mAP@.5 mAP@.5:.95: 100% 1/1 [00:00<00:00,  3.99it/s]
#                    all         20        125      0.428     0.0538     0.0717     0.0199
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       6/149      1.84G    0.09179    0.06807    0.03153         44        416: 100% 5/5 [00:00<00:00,  5.62it/s]
#                  Class     Images  Instances          P          R     mAP@.5 mAP@.5:.95: 100% 1/1 [00:00<00:00,  5.05it/s]
#                    all         20        125      0.789      0.144      0.112     0.0401
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       7/149      1.84G    0.08458    0.06499    0.03027         67        416: 100% 5/5 [00:00<00:00,  5.70it/s]
#                  Class     Images  Instances          P          R     mAP@.5 mAP@.5:.95: 100% 1/1 [00:00<00:00,  4.32it/s]
#                    all         20        125      0.807       0.18      0.138     0.0417
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       8/149      1.84G    0.08331    0.05956    0.02784         59        416: 100% 5/5 [00:00<00:00,  5.31it/s]
#                  Class     Images  Instances          P          R     mAP@.5 mAP@.5:.95: 100% 1/1 [00:00<00:00,  4.30it/s]
#                    all         20        125       0.83      0.151      0.169     0.0706
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       9/149      1.84G    0.08012    0.06102    0.02601         47        416: 100% 5/5 [00:00<00:00,  5.61it/s]
#                  Class     Images  Instances          P          R     mAP@.5 mAP@.5:.95: 100% 1/1 [00:00<00:00,  4.34it/s]
#                    all         20        125     0.0811      0.368     0.0994      0.032
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      10/149      1.84G    0.08135    0.05847    0.02473         59        416: 100% 5/5 [00:00<00:00,  5.53it/s]
#                  Class     Images  Instances          P          R     mAP@.5 mAP@.5:.95: 100% 1/1 [00:00<00:00,  3.94it/s]
#                    all         20        125      0.462      0.387      0.231     0.0781
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      11/149      1.84G    0.07898    0.05528    0.02436         57        416: 100% 5/5 [00:00<00:00,  5.45it/s]
#                  Class     Images  Instances          P          R     mAP@.5 mAP@.5:.95: 100% 1/1 [00:00<00:00,  4.44it/s]
#                    all         20        125      0.486      0.295      0.178     0.0577
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      12/149      1.84G    0.07846    0.06072    0.02408        108        416: 100% 5/5 [00:00<00:00,  5.98it/s]
#                  Class     Images  Instances          P          R     mAP@.5 mAP@.5:.95: 100% 1/1 [00:00<00:00,  4.26it/s]
#                    all         20        125      0.615      0.342      0.334      0.111
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      13/149      1.84G    0.07238    0.05574    0.02196         97        416: 100% 5/5 [00:00<00:00,  5.59it/s]
#                  Class     Images  Instances          P          R     mAP@.5 mAP@.5:.95: 100% 1/1 [00:00<00:00,  4.11it/s]
#                    all         20        125      0.111      0.634      0.177     0.0662
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      14/149      1.84G    0.07974    0.05054    0.02127         77        416: 100% 5/5 [00:00<00:00,  5.33it/s]
#                  Class     Images  Instances          P          R     mAP@.5 mAP@.5:.95: 100% 1/1 [00:00<00:00,  5.32it/s]
#                    all         20        125      0.531      0.354      0.271     0.0937
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      15/149      1.84G     0.0786    0.04966    0.01943         49        416: 100% 5/5 [00:00<00:00,  5.74it/s]
#                  Class     Images  Instances          P          R     mAP@.5 mAP@.5:.95: 100% 1/1 [00:00<00:00,  5.06it/s]
#                    all         20        125      0.618      0.319      0.332      0.114
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      16/149      1.84G    0.07629     0.0537     0.0191        101        416: 100% 5/5 [00:00<00:00,  5.60it/s]
#                  Class     Images  Instances          P          R     mAP@.5 mAP@.5:.95: 100% 1/1 [00:00<00:00,  5.48it/s]
#                    all         20        125      0.562      0.313        0.3      0.102
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      17/149      1.84G    0.07789    0.05286    0.01835        111        416: 100% 5/5 [00:00<00:00,  5.60it/s]
#                  Class     Images  Instances          P          R     mAP@.5 mAP@.5:.95: 100% 1/1 [00:00<00:00,  5.03it/s]
#                    all         20        125      0.591      0.411      0.311      0.106
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      18/149      1.84G    0.08119    0.05251    0.01877         92        416: 100% 5/5 [00:00<00:00,  5.73it/s]
#                  Class     Images  Instances          P          R     mAP@.5 mAP@.5:.95: 100% 1/1 [00:00<00:00,  5.07it/s]
#                    all         20        125      0.173      0.623      0.206     0.0604
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      19/149      1.84G    0.07436    0.04653    0.01652         46        416: 100% 5/5 [00:00<00:00,  5.38it/s]
#                  Class     Images  Instances          P          R     mAP@.5 mAP@.5:.95: 100% 1/1 [00:00<00:00,  4.92it/s]
#                    all         20        125      0.526      0.364       0.26     0.0872
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      20/149      1.84G    0.07441    0.04484    0.01765         50        416: 100% 5/5 [00:00<00:00,  5.67it/s]
#                  Class     Images  Instances          P          R     mAP@.5 mAP@.5:.95: 100% 1/1 [00:00<00:00,  5.22it/s]
#                    all         20        125       0.52      0.357      0.311      0.101
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      21/149      1.84G    0.07276    0.04833    0.01691         52        416: 100% 5/5 [00:00<00:00,  5.92it/s]
#                  Class     Images  Instances          P          R     mAP@.5 mAP@.5:.95: 100% 1/1 [00:00<00:00,  5.53it/s]
#                    all         20        125      0.607      0.451      0.424      0.174
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      22/149      1.84G    0.06882    0.04946     0.0157         99        416: 100% 5/5 [00:00<00:00,  5.83it/s]
#                  Class     Images  Instances          P          R     mAP@.5 mAP@.5:.95: 100% 1/1 [00:00<00:00,  4.81it/s]
#                    all         20        125       0.66      0.356      0.426      0.165
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      23/149      1.84G    0.06282    0.04937    0.01594         69        416: 100% 5/5 [00:00<00:00,  5.71it/s]
#                  Class     Images  Instances          P          R     mAP@.5 mAP@.5:.95: 100% 1/1 [00:00<00:00,  4.47it/s]
#                    all         20        125      0.559      0.415      0.324      0.137
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      24/149      1.84G    0.07604    0.04756    0.01649         39        416: 100% 5/5 [00:00<00:00,  5.70it/s]
#                  Class     Images  Instances          P          R     mAP@.5 mAP@.5:.95: 100% 1/1 [00:00<00:00,  4.92it/s]
#                    all         20        125      0.646      0.441      0.476      0.212
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      25/149      1.84G    0.07225    0.05132    0.01621         84        416: 100% 5/5 [00:00<00:00,  5.81it/s]
#                  Class     Images  Instances          P          R     mAP@.5 mAP@.5:.95: 100% 1/1 [00:00<00:00,  5.74it/s]
#                    all         20        125      0.599      0.446       0.42      0.137
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      26/149      1.84G    0.07093    0.05289    0.01541         93        416: 100% 5/5 [00:00<00:00,  5.66it/s]
#                  Class     Images  Instances          P          R     mAP@.5 mAP@.5:.95: 100% 1/1 [00:00<00:00,  5.75it/s]
#                    all         20        125      0.709       0.47      0.516      0.205
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      27/149      1.84G    0.06093    0.05054    0.01566         55        416: 100% 5/5 [00:00<00:00,  5.56it/s]
#                  Class     Images  Instances          P          R     mAP@.5 mAP@.5:.95: 100% 1/1 [00:00<00:00,  5.84it/s]
#                    all         20        125      0.745      0.387      0.516      0.206
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      28/149      1.84G     0.0732    0.03772    0.01353         26        416: 100% 5/5 [00:00<00:00,  5.84it/s]
#                  Class     Images  Instances          P          R     mAP@.5 mAP@.5:.95: 100% 1/1 [00:00<00:00,  5.25it/s]
#                    all         20        125      0.555      0.633      0.539      0.205
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      29/149      1.84G    0.06503    0.04591    0.01279         40        416: 100% 5/5 [00:00<00:00,  6.21it/s]
#                  Class     Images  Instances          P          R     mAP@.5 mAP@.5:.95: 100% 1/1 [00:00<00:00,  5.15it/s]
#                    all         20        125      0.204      0.663      0.339      0.143
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      30/149      1.84G    0.06901    0.04663    0.01191        128        416: 100% 5/5 [00:00<00:00,  5.91it/s]
#                  Class     Images  Instances          P          R     mAP@.5 mAP@.5:.95: 100% 1/1 [00:00<00:00,  5.44it/s]
#                    all         20        125      0.391      0.751      0.618      0.258
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      31/149      1.84G    0.05419    0.04565    0.01145         54        416: 100% 5/5 [00:00<00:00,  5.40it/s]
#                  Class     Images  Instances          P          R     mAP@.5 mAP@.5:.95: 100% 1/1 [00:00<00:00,  5.99it/s]
#                    all         20        125      0.272       0.65      0.342      0.124
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      32/149      1.84G     0.0675    0.04601    0.01173         50        416: 100% 5/5 [00:00<00:00,  5.74it/s]
#                  Class     Images  Instances          P          R     mAP@.5 mAP@.5:.95: 100% 1/1 [00:00<00:00,  5.59it/s]
#                    all         20        125        0.4      0.615      0.461      0.195
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      33/149      1.84G    0.06099    0.04379    0.01031         51        416: 100% 5/5 [00:00<00:00,  6.06it/s]
#                  Class     Images  Instances          P          R     mAP@.5 mAP@.5:.95: 100% 1/1 [00:00<00:00,  5.14it/s]
#                    all         20        125      0.361      0.633       0.48      0.194
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      34/149      1.84G    0.06051     0.0493    0.01209         67        416: 100% 5/5 [00:00<00:00,  5.75it/s]
#                  Class     Images  Instances          P          R     mAP@.5 mAP@.5:.95: 100% 1/1 [00:00<00:00,  5.61it/s]
#                    all         20        125      0.396        0.7      0.593      0.251
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      35/149      1.84G    0.05501    0.04594    0.01224         72        416: 100% 5/5 [00:00<00:00,  5.34it/s]
#                  Class     Images  Instances          P          R     mAP@.5 mAP@.5:.95: 100% 1/1 [00:00<00:00,  7.49it/s]
#                    all         20        125      0.278       0.77      0.431      0.161
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      36/149      1.84G    0.06411    0.04201    0.01103         42        416: 100% 5/5 [00:00<00:00,  5.77it/s]
#                  Class     Images  Instances          P          R     mAP@.5 mAP@.5:.95: 100% 1/1 [00:00<00:00,  6.24it/s]
#                    all         20        125      0.351      0.645      0.496      0.222
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      37/149      1.84G    0.06221    0.04225    0.01271         81        416: 100% 5/5 [00:00<00:00,  5.18it/s]
#                  Class     Images  Instances          P          R     mAP@.5 mAP@.5:.95: 100% 1/1 [00:00<00:00,  4.00it/s]
#                    all         20        125      0.319      0.711      0.542      0.259
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      38/149      1.84G    0.05755    0.04818    0.01151         75        416: 100% 5/5 [00:00<00:00,  5.76it/s]
#                  Class     Images  Instances          P          R     mAP@.5 mAP@.5:.95: 100% 1/1 [00:00<00:00,  5.27it/s]
#                    all         20        125      0.472      0.782      0.693      0.371
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      39/149      1.84G    0.05309    0.04829    0.01267         79        416: 100% 5/5 [00:00<00:00,  5.42it/s]
#                  Class     Images  Instances          P          R     mAP@.5 mAP@.5:.95: 100% 1/1 [00:00<00:00,  6.31it/s]
#                    all         20        125        0.4      0.711      0.568       0.29
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      40/149      1.84G    0.06161    0.04568    0.01073         85        416: 100% 5/5 [00:00<00:00,  5.52it/s]
#                  Class     Images  Instances          P          R     mAP@.5 mAP@.5:.95: 100% 1/1 [00:00<00:00,  5.21it/s]
#                    all         20        125      0.478      0.703      0.592      0.288
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      41/149      1.84G    0.05806    0.04921    0.01152         60        416: 100% 5/5 [00:00<00:00,  5.99it/s]
#                  Class     Images  Instances          P          R     mAP@.5 mAP@.5:.95: 100% 1/1 [00:00<00:00,  5.18it/s]
#                    all         20        125      0.519        0.8      0.666      0.303
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      42/149      1.84G    0.05178      0.043   0.009088         49        416: 100% 5/5 [00:00<00:00,  6.27it/s]
#                  Class     Images  Instances          P          R     mAP@.5 mAP@.5:.95: 100% 1/1 [00:00<00:00,  4.44it/s]
#                    all         20        125      0.666      0.851      0.808      0.415
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      43/149      1.84G    0.04886    0.04712    0.01009         82        416: 100% 5/5 [00:00<00:00,  5.31it/s]
#                  Class     Images  Instances          P          R     mAP@.5 mAP@.5:.95: 100% 1/1 [00:00<00:00,  7.27it/s]
#                    all         20        125      0.528      0.767      0.741      0.357
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      44/149      1.84G    0.05523    0.04377   0.009918         38        416: 100% 5/5 [00:00<00:00,  5.86it/s]
#                  Class     Images  Instances          P          R     mAP@.5 mAP@.5:.95: 100% 1/1 [00:00<00:00,  5.63it/s]
#                    all         20        125      0.542      0.735      0.679      0.329
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      45/149      1.84G    0.05304    0.04526   0.009538         83        416: 100% 5/5 [00:00<00:00,  5.48it/s]
#                  Class     Images  Instances          P          R     mAP@.5 mAP@.5:.95: 100% 1/1 [00:00<00:00,  5.23it/s]
#                    all         20        125      0.646      0.721      0.755      0.375
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      46/149      1.84G    0.05187    0.04841   0.009248         86        416: 100% 5/5 [00:01<00:00,  4.91it/s]
#                  Class     Images  Instances          P          R     mAP@.5 mAP@.5:.95: 100% 1/1 [00:00<00:00,  5.21it/s]
#                    all         20        125      0.585      0.739      0.755      0.393
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      47/149      1.84G    0.04713     0.0465   0.008819         64        416: 100% 5/5 [00:00<00:00,  5.44it/s]
#                  Class     Images  Instances          P          R     mAP@.5 mAP@.5:.95: 100% 1/1 [00:00<00:00,  6.43it/s]
#                    all         20        125      0.534       0.71      0.631      0.283
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      48/149      1.84G    0.05774    0.04275     0.0087         69        416: 100% 5/5 [00:01<00:00,  4.76it/s]
#                  Class     Images  Instances          P          R     mAP@.5 mAP@.5:.95: 100% 1/1 [00:00<00:00,  3.67it/s]
#                    all         20        125      0.447      0.787      0.604      0.303
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      49/149      1.84G    0.05441    0.03945   0.009577         59        416: 100% 5/5 [00:01<00:00,  3.81it/s]
#                  Class     Images  Instances          P          R     mAP@.5 mAP@.5:.95: 100% 1/1 [00:00<00:00,  2.97it/s]
#                    all         20        125      0.591      0.757      0.731      0.403
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      50/149      1.84G    0.05026    0.04205   0.008901         88        416: 100% 5/5 [00:00<00:00,  5.93it/s]
#                  Class     Images  Instances          P          R     mAP@.5 mAP@.5:.95: 100% 1/1 [00:00<00:00,  5.13it/s]
#                    all         20        125      0.676      0.827      0.773      0.362
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      51/149      1.84G    0.05105    0.05047   0.008049         86        416: 100% 5/5 [00:00<00:00,  5.49it/s]
#                  Class     Images  Instances          P          R     mAP@.5 mAP@.5:.95: 100% 1/1 [00:00<00:00,  5.16it/s]
#                    all         20        125      0.673      0.813      0.823      0.435
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      52/149      1.84G    0.05226      0.048   0.008643         47        416: 100% 5/5 [00:00<00:00,  5.88it/s]
#                  Class     Images  Instances          P          R     mAP@.5 mAP@.5:.95: 100% 1/1 [00:00<00:00,  5.41it/s]
#                    all         20        125      0.676      0.862      0.804      0.416
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      53/149      1.84G    0.04814    0.04664   0.009108         96        416: 100% 5/5 [00:00<00:00,  5.58it/s]
#                  Class     Images  Instances          P          R     mAP@.5 mAP@.5:.95: 100% 1/1 [00:00<00:00,  5.31it/s]
#                    all         20        125      0.656      0.814      0.794      0.419
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      54/149      1.84G    0.04964    0.04737   0.008156         93        416: 100% 5/5 [00:00<00:00,  5.33it/s]
#                  Class     Images  Instances          P          R     mAP@.5 mAP@.5:.95: 100% 1/1 [00:00<00:00,  5.64it/s]
#                    all         20        125      0.718      0.787      0.792      0.434
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      55/149      1.84G    0.04752    0.04956   0.008128         83        416: 100% 5/5 [00:00<00:00,  5.45it/s]
#                  Class     Images  Instances          P          R     mAP@.5 mAP@.5:.95: 100% 1/1 [00:00<00:00,  7.04it/s]
#                    all         20        125      0.592      0.763      0.723      0.299
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      56/149      1.84G     0.0541     0.0389    0.00885         58        416: 100% 5/5 [00:00<00:00,  5.81it/s]
#                  Class     Images  Instances          P          R     mAP@.5 mAP@.5:.95: 100% 1/1 [00:00<00:00,  4.89it/s]
#                    all         20        125      0.774      0.793      0.858      0.469
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      57/149      1.84G     0.0485    0.04183   0.006988         85        416: 100% 5/5 [00:00<00:00,  5.34it/s]
#                  Class     Images  Instances          P          R     mAP@.5 mAP@.5:.95: 100% 1/1 [00:00<00:00,  5.35it/s]
#                    all         20        125      0.729      0.691      0.785      0.391
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      58/149      1.84G    0.05012    0.05098   0.008814         77        416: 100% 5/5 [00:00<00:00,  5.47it/s]
#                  Class     Images  Instances          P          R     mAP@.5 mAP@.5:.95: 100% 1/1 [00:00<00:00,  6.26it/s]
#                    all         20        125      0.776      0.798      0.846      0.446
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      59/149      1.84G    0.04166    0.03886   0.006419         56        416: 100% 5/5 [00:00<00:00,  5.75it/s]
#                  Class     Images  Instances          P          R     mAP@.5 mAP@.5:.95: 100% 1/1 [00:00<00:00,  4.32it/s]
#                    all         20        125      0.687      0.713      0.791      0.392
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      60/149      1.84G      0.052    0.04707    0.00884         93        416: 100% 5/5 [00:00<00:00,  6.08it/s]
#                  Class     Images  Instances          P          R     mAP@.5 mAP@.5:.95: 100% 1/1 [00:00<00:00,  5.74it/s]
#                    all         20        125      0.714      0.714      0.823      0.409
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      61/149      1.84G     0.0454    0.03946       0.01         47        416: 100% 5/5 [00:00<00:00,  5.90it/s]
#                  Class     Images  Instances          P          R     mAP@.5 mAP@.5:.95: 100% 1/1 [00:00<00:00,  5.45it/s]
#                    all         20        125      0.673       0.75      0.766      0.406
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      62/149      1.84G    0.04629    0.04351   0.007517         72        416: 100% 5/5 [00:00<00:00,  5.76it/s]
#                  Class     Images  Instances          P          R     mAP@.5 mAP@.5:.95: 100% 1/1 [00:00<00:00,  5.42it/s]
#                    all         20        125      0.727      0.792      0.836      0.422
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      63/149      1.84G    0.04346    0.03954   0.007646         53        416: 100% 5/5 [00:00<00:00,  5.36it/s]
#                  Class     Images  Instances          P          R     mAP@.5 mAP@.5:.95: 100% 1/1 [00:00<00:00,  5.79it/s]
#                    all         20        125      0.667      0.661      0.704      0.354
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      64/149      1.84G    0.05105    0.04554   0.007385         73        416: 100% 5/5 [00:00<00:00,  5.62it/s]
#                  Class     Images  Instances          P          R     mAP@.5 mAP@.5:.95: 100% 1/1 [00:00<00:00,  5.53it/s]
#                    all         20        125      0.668      0.796      0.793      0.471
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      65/149      1.84G    0.04745    0.04797   0.007354         98        416: 100% 5/5 [00:00<00:00,  5.98it/s]
#                  Class     Images  Instances          P          R     mAP@.5 mAP@.5:.95: 100% 1/1 [00:00<00:00,  5.82it/s]
#                    all         20        125       0.71      0.795      0.823       0.43
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      66/149      1.84G    0.04632    0.04333   0.007903         84        416: 100% 5/5 [00:00<00:00,  5.75it/s]
#                  Class     Images  Instances          P          R     mAP@.5 mAP@.5:.95: 100% 1/1 [00:00<00:00,  5.29it/s]
#                    all         20        125      0.763      0.817      0.857      0.488
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      67/149      1.84G    0.04378    0.04781   0.007316         71        416: 100% 5/5 [00:00<00:00,  5.72it/s]
#                  Class     Images  Instances          P          R     mAP@.5 mAP@.5:.95: 100% 1/1 [00:00<00:00,  5.98it/s]
#                    all         20        125      0.715      0.696      0.788      0.404
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      68/149      1.84G    0.05046    0.03969   0.009109         55        416: 100% 5/5 [00:00<00:00,  6.12it/s]
#                  Class     Images  Instances          P          R     mAP@.5 mAP@.5:.95: 100% 1/1 [00:00<00:00,  6.15it/s]
#                    all         20        125      0.806      0.767      0.864      0.521
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      69/149      1.84G    0.04238    0.03841   0.007515         73        416: 100% 5/5 [00:00<00:00,  5.81it/s]
#                  Class     Images  Instances          P          R     mAP@.5 mAP@.5:.95: 100% 1/1 [00:00<00:00,  5.28it/s]
#                    all         20        125      0.808      0.744      0.853       0.46
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      70/149      1.84G    0.04616    0.03741   0.007484         47        416: 100% 5/5 [00:00<00:00,  5.78it/s]
#                  Class     Images  Instances          P          R     mAP@.5 mAP@.5:.95: 100% 1/1 [00:00<00:00,  5.23it/s]
#                    all         20        125      0.864       0.75      0.891      0.514
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      71/149      1.84G    0.04063    0.04013   0.006217         65        416: 100% 5/5 [00:00<00:00,  5.50it/s]
#                  Class     Images  Instances          P          R     mAP@.5 mAP@.5:.95: 100% 1/1 [00:00<00:00,  5.71it/s]
#                    all         20        125      0.641      0.755      0.742      0.409
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      72/149      1.84G    0.05205    0.04943   0.007126        144        416: 100% 5/5 [00:00<00:00,  5.59it/s]
#                  Class     Images  Instances          P          R     mAP@.5 mAP@.5:.95: 100% 1/1 [00:00<00:00,  5.37it/s]
#                    all         20        125      0.782       0.76      0.794      0.449
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      73/149      1.84G     0.0467    0.04138   0.008415         91        416: 100% 5/5 [00:00<00:00,  5.95it/s]
#                  Class     Images  Instances          P          R     mAP@.5 mAP@.5:.95: 100% 1/1 [00:00<00:00,  5.45it/s]
#                    all         20        125      0.688      0.767      0.761      0.429
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      74/149      1.84G    0.04444    0.03962   0.007215         70        416: 100% 5/5 [00:00<00:00,  6.22it/s]
#                  Class     Images  Instances          P          R     mAP@.5 mAP@.5:.95: 100% 1/1 [00:00<00:00,  4.30it/s]
#                    all         20        125      0.661      0.765       0.75      0.421
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      75/149      1.84G     0.0429    0.03712   0.009481         30        416: 100% 5/5 [00:00<00:00,  6.00it/s]
#                  Class     Images  Instances          P          R     mAP@.5 mAP@.5:.95: 100% 1/1 [00:00<00:00,  5.32it/s]
#                    all         20        125      0.675      0.773      0.745      0.416
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      76/149      1.84G    0.04634    0.03921   0.007085         83        416: 100% 5/5 [00:00<00:00,  5.67it/s]
#                  Class     Images  Instances          P          R     mAP@.5 mAP@.5:.95: 100% 1/1 [00:00<00:00,  5.26it/s]
#                    all         20        125       0.82      0.797      0.875      0.539
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      77/149      1.84G    0.04346     0.0448   0.007325         83        416: 100% 5/5 [00:00<00:00,  5.71it/s]
#                  Class     Images  Instances          P          R     mAP@.5 mAP@.5:.95: 100% 1/1 [00:00<00:00,  5.80it/s]
#                    all         20        125       0.89      0.788      0.878      0.509
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      78/149      1.84G    0.04381    0.04404   0.006928         64        416: 100% 5/5 [00:00<00:00,  5.23it/s]
#                  Class     Images  Instances          P          R     mAP@.5 mAP@.5:.95: 100% 1/1 [00:00<00:00,  6.15it/s]
#                    all         20        125      0.818      0.777      0.849      0.508
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      79/149      1.84G     0.0407    0.04255   0.006876         66        416: 100% 5/5 [00:00<00:00,  5.69it/s]
#                  Class     Images  Instances          P          R     mAP@.5 mAP@.5:.95: 100% 1/1 [00:00<00:00,  6.31it/s]
#                    all         20        125      0.776      0.862      0.857      0.498
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      80/149      1.84G    0.04219    0.03599   0.006421         55        416: 100% 5/5 [00:00<00:00,  6.06it/s]
#                  Class     Images  Instances          P          R     mAP@.5 mAP@.5:.95: 100% 1/1 [00:00<00:00,  5.26it/s]
#                    all         20        125      0.876      0.784       0.88      0.523
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      81/149      1.84G    0.04209    0.03694     0.0068         63        416: 100% 5/5 [00:00<00:00,  5.61it/s]
#                  Class     Images  Instances          P          R     mAP@.5 mAP@.5:.95: 100% 1/1 [00:00<00:00,  5.35it/s]
#                    all         20        125      0.884      0.779      0.882      0.525
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      82/149      1.84G    0.04052    0.04442   0.007012         82        416: 100% 5/5 [00:00<00:00,  6.20it/s]
#                  Class     Images  Instances          P          R     mAP@.5 mAP@.5:.95: 100% 1/1 [00:00<00:00,  5.22it/s]
#                    all         20        125      0.905       0.78       0.89      0.502
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      83/149      1.84G    0.03743    0.03478   0.006346         73        416: 100% 5/5 [00:00<00:00,  5.66it/s]
#                  Class     Images  Instances          P          R     mAP@.5 mAP@.5:.95: 100% 1/1 [00:00<00:00,  6.08it/s]
#                    all         20        125      0.719      0.881      0.854      0.521
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      84/149      1.84G    0.04364    0.04256    0.00694         87        416: 100% 5/5 [00:00<00:00,  5.66it/s]
#                  Class     Images  Instances          P          R     mAP@.5 mAP@.5:.95: 100% 1/1 [00:00<00:00,  4.99it/s]
#                    all         20        125      0.847      0.752      0.873      0.533
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      85/149      1.84G    0.04059     0.0369   0.005107         44        416: 100% 5/5 [00:00<00:00,  5.57it/s]
#                  Class     Images  Instances          P          R     mAP@.5 mAP@.5:.95: 100% 1/1 [00:00<00:00,  5.36it/s]
#                    all         20        125      0.842      0.819      0.885      0.557
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      86/149      1.84G    0.04189    0.04371   0.007846         77        416: 100% 5/5 [00:00<00:00,  6.33it/s]
#                  Class     Images  Instances          P          R     mAP@.5 mAP@.5:.95: 100% 1/1 [00:00<00:00,  3.94it/s]
#                    all         20        125      0.847      0.862      0.896      0.577
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      87/149      1.84G       0.04    0.03732   0.007088         44        416: 100% 5/5 [00:00<00:00,  5.45it/s]
#                  Class     Images  Instances          P          R     mAP@.5 mAP@.5:.95: 100% 1/1 [00:00<00:00,  6.19it/s]
#                    all         20        125      0.866      0.781      0.891       0.56
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      88/149      1.84G    0.04233    0.04099   0.005276         81        416: 100% 5/5 [00:00<00:00,  6.12it/s]
#                  Class     Images  Instances          P          R     mAP@.5 mAP@.5:.95: 100% 1/1 [00:00<00:00,  4.87it/s]
#                    all         20        125      0.812      0.874      0.897      0.526
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      89/149      1.84G    0.04133    0.03794   0.006267         72        416: 100% 5/5 [00:00<00:00,  5.58it/s]
#                  Class     Images  Instances          P          R     mAP@.5 mAP@.5:.95: 100% 1/1 [00:00<00:00,  7.03it/s]
#                    all         20        125      0.951      0.757      0.898      0.544
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      90/149      1.84G    0.03752    0.03817   0.006308         33        416: 100% 5/5 [00:00<00:00,  5.88it/s]
#                  Class     Images  Instances          P          R     mAP@.5 mAP@.5:.95: 100% 1/1 [00:00<00:00,  5.70it/s]
#                    all         20        125      0.784      0.871      0.903      0.547
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      91/149      1.84G     0.0363    0.03857   0.008102         34        416: 100% 5/5 [00:00<00:00,  5.57it/s]
#                  Class     Images  Instances          P          R     mAP@.5 mAP@.5:.95: 100% 1/1 [00:00<00:00,  5.42it/s]
#                    all         20        125      0.952      0.737      0.885      0.545
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      92/149      1.84G    0.04137    0.04178   0.006162         47        416: 100% 5/5 [00:00<00:00,  5.95it/s]
#                  Class     Images  Instances          P          R     mAP@.5 mAP@.5:.95: 100% 1/1 [00:00<00:00,  5.64it/s]
#                    all         20        125      0.921      0.738      0.898       0.51
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      93/149      1.84G    0.04212    0.03834     0.0065         67        416: 100% 5/5 [00:00<00:00,  5.78it/s]
#                  Class     Images  Instances          P          R     mAP@.5 mAP@.5:.95: 100% 1/1 [00:00<00:00,  5.21it/s]
#                    all         20        125      0.824      0.837      0.885      0.574
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      94/149      1.84G    0.03854    0.03971   0.006208         50        416: 100% 5/5 [00:00<00:00,  5.80it/s]
#                  Class     Images  Instances          P          R     mAP@.5 mAP@.5:.95: 100% 1/1 [00:00<00:00,  5.46it/s]
#                    all         20        125      0.818      0.844      0.887      0.553
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      95/149      1.84G    0.03843    0.03343    0.00644         39        416: 100% 5/5 [00:00<00:00,  5.26it/s]
#                  Class     Images  Instances          P          R     mAP@.5 mAP@.5:.95: 100% 1/1 [00:00<00:00,  6.73it/s]
#                    all         20        125      0.832      0.813      0.887      0.539
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      96/149      1.84G    0.04014    0.03794    0.00547         62        416: 100% 5/5 [00:00<00:00,  5.94it/s]
#                  Class     Images  Instances          P          R     mAP@.5 mAP@.5:.95: 100% 1/1 [00:00<00:00,  5.23it/s]
#                    all         20        125      0.872      0.747      0.878      0.572
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      97/149      1.84G     0.0389    0.03984   0.006173         57        416: 100% 5/5 [00:00<00:00,  5.65it/s]
#                  Class     Images  Instances          P          R     mAP@.5 mAP@.5:.95: 100% 1/1 [00:00<00:00,  5.58it/s]
#                    all         20        125      0.874       0.78      0.892      0.574
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      98/149      1.84G    0.03672    0.03777    0.00654         27        416: 100% 5/5 [00:00<00:00,  6.15it/s]
#                  Class     Images  Instances          P          R     mAP@.5 mAP@.5:.95: 100% 1/1 [00:00<00:00,  4.35it/s]
#                    all         20        125      0.856      0.787      0.887      0.573
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      99/149      1.84G    0.03818     0.0424   0.008544         70        416: 100% 5/5 [00:00<00:00,  5.37it/s]
#                  Class     Images  Instances          P          R     mAP@.5 mAP@.5:.95: 100% 1/1 [00:00<00:00,  6.96it/s]
#                    all         20        125      0.893      0.776      0.894      0.566
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#     100/149      1.84G    0.04042    0.03785   0.006486         73        416: 100% 5/5 [00:00<00:00,  5.98it/s]
#                  Class     Images  Instances          P          R     mAP@.5 mAP@.5:.95: 100% 1/1 [00:00<00:00,  4.63it/s]
#                    all         20        125      0.904      0.774      0.905      0.576
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#     101/149      1.84G    0.03634    0.04061   0.006298         32        416: 100% 5/5 [00:00<00:00,  5.81it/s]
#                  Class     Images  Instances          P          R     mAP@.5 mAP@.5:.95: 100% 1/1 [00:00<00:00,  5.25it/s]
#                    all         20        125      0.918      0.775      0.908      0.572
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#     102/149      1.84G    0.03881    0.03817   0.006039         94        416: 100% 5/5 [00:00<00:00,  5.73it/s]
#                  Class     Images  Instances          P          R     mAP@.5 mAP@.5:.95: 100% 1/1 [00:00<00:00,  6.41it/s]
#                    all         20        125      0.918      0.781      0.897      0.556
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#     103/149      1.84G    0.03686    0.03632   0.006273         69        416: 100% 5/5 [00:00<00:00,  5.49it/s]
#                  Class     Images  Instances          P          R     mAP@.5 mAP@.5:.95: 100% 1/1 [00:00<00:00,  6.05it/s]
#                    all         20        125      0.881      0.802      0.906      0.512
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
# ...
#                    all         20        125      0.915      0.827      0.911      0.573
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#     113/149      1.84G    0.03825    0.03376   0.006901         73        416: 100% 5/5 [00:00<00:00,  5.76it/s]
#                  Class     Images  Instances          P          R     mAP@.5 mAP@.5:.95: 100% 1/1 [00:00<00:00,  5.44it/s]
#                    all         20        125      0.876      0.859      0.911      0.578
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#     114/149      1.84G    0.03796    0.04119   0.008039         79        416: 100% 5/5 [00:00<00:00,  5.34it/s]
#                  Class     Images  Instances          P          R     mAP@.5 mAP@.5:.95: 100% 1/1 [00:00<00:00,  6.20it/s]
#                    all         20        125      0.879      0.856      0.913      0.582
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#     115/149      1.84G    0.03542    0.04026   0.005575         48        416: 100% 5/5 [00:00<00:00,  5.21it/s]
#                  Class     Images  Instances          P          R     mAP@.5 mAP@.5:.95: 100% 1/1 [00:00<00:00,  6.78it/s]
#                    all         20        125      0.868      0.873      0.913      0.585
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#     116/149      1.84G    0.03537    0.03539   0.004769         49        416: 100% 5/5 [00:01<00:00,  3.49it/s]
#                  Class     Images  Instances          P          R     mAP@.5 mAP@.5:.95: 100% 1/1 [00:00<00:00,  3.83it/s]
#                    all         20        125      0.887      0.839      0.912      0.575
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#     117/149      1.84G    0.03592     0.0373   0.005387        100        416: 100% 5/5 [00:01<00:00,  4.17it/s]
#                  Class     Images  Instances          P          R     mAP@.5 mAP@.5:.95: 100% 1/1 [00:00<00:00,  5.38it/s]
#                    all         20        125      0.883      0.869      0.916      0.599
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#     118/149      1.84G    0.03552    0.03388   0.005825         47        416: 100% 5/5 [00:00<00:00,  5.68it/s]
#                  Class     Images  Instances          P          R     mAP@.5 mAP@.5:.95: 100% 1/1 [00:00<00:00,  5.98it/s]
#                    all         20        125      0.883      0.866      0.915      0.605
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#     119/149      1.84G    0.03646    0.03505   0.006258         64        416: 100% 5/5 [00:00<00:00,  5.91it/s]
#                  Class     Images  Instances          P          R     mAP@.5 mAP@.5:.95: 100% 1/1 [00:00<00:00,  5.71it/s]
#                    all         20        125      0.887      0.864      0.923      0.585
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#     120/149      1.84G    0.03377    0.03249   0.006492         54        416: 100% 5/5 [00:00<00:00,  5.85it/s]
#                  Class     Images  Instances          P          R     mAP@.5 mAP@.5:.95: 100% 1/1 [00:00<00:00,  5.04it/s]
#                    all         20        125       0.89      0.864      0.916      0.614
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#     121/149      1.84G    0.03498    0.03779   0.005567         70        416: 100% 5/5 [00:00<00:00,  5.62it/s]
#                  Class     Images  Instances          P          R     mAP@.5 mAP@.5:.95: 100% 1/1 [00:00<00:00,  5.46it/s]
#                    all         20        125      0.895      0.862      0.916      0.607
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#     122/149      1.84G    0.03576    0.03814   0.007201         73        416: 100% 5/5 [00:00<00:00,  5.55it/s]
#                  Class     Images  Instances          P          R     mAP@.5 mAP@.5:.95: 100% 1/1 [00:00<00:00,  6.31it/s]
#                    all         20        125      0.897      0.862      0.919      0.601
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#     123/149      1.84G    0.03504    0.03576   0.006153         64        416: 100% 5/5 [00:00<00:00,  5.25it/s]
#                  Class     Images  Instances          P          R     mAP@.5 mAP@.5:.95: 100% 1/1 [00:00<00:00,  6.79it/s]
#                    all         20        125        0.9      0.863      0.918        0.6
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#     124/149      1.84G    0.03608    0.03754   0.005299         68        416: 100% 5/5 [00:00<00:00,  5.87it/s]
#                  Class     Images  Instances          P          R     mAP@.5 mAP@.5:.95: 100% 1/1 [00:00<00:00,  5.42it/s]
#                    all         20        125      0.899      0.865       0.92      0.612
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#     125/149      1.84G    0.03407    0.03711   0.004011         79        416: 100% 5/5 [00:00<00:00,  5.72it/s]
#                  Class     Images  Instances          P          R     mAP@.5 mAP@.5:.95: 100% 1/1 [00:00<00:00,  4.92it/s]
#                    all         20        125      0.899      0.865      0.921      0.599
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#     126/149      1.84G    0.03478    0.03855   0.005475         62        416: 100% 5/5 [00:00<00:00,  5.65it/s]
#                  Class     Images  Instances          P          R     mAP@.5 mAP@.5:.95: 100% 1/1 [00:00<00:00,  6.88it/s]
#                    all         20        125      0.896      0.866      0.923      0.609
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#     127/149      1.84G    0.03497    0.03865   0.004932         90        416: 100% 5/5 [00:00<00:00,  5.46it/s]
#                  Class     Images  Instances          P          R     mAP@.5 mAP@.5:.95: 100% 1/1 [00:00<00:00,  5.15it/s]
#                    all         20        125      0.893      0.871       0.92       0.61
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#     128/149      1.84G    0.03431    0.03766   0.004581         66        416: 100% 5/5 [00:00<00:00,  5.88it/s]
#                  Class     Images  Instances          P          R     mAP@.5 mAP@.5:.95: 100% 1/1 [00:00<00:00,  5.19it/s]
#                    all         20        125      0.886       0.86      0.913      0.596
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#     129/149      1.84G    0.03574    0.03682   0.004747         98        416: 100% 5/5 [00:00<00:00,  5.83it/s]
#                  Class     Images  Instances          P          R     mAP@.5 mAP@.5:.95: 100% 1/1 [00:00<00:00,  5.51it/s]
#                    all         20        125      0.889      0.859      0.914      0.603
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#     130/149      1.84G    0.03521    0.03561   0.006431         60        416: 100% 5/5 [00:00<00:00,  5.49it/s]
#                  Class     Images  Instances          P          R     mAP@.5 mAP@.5:.95: 100% 1/1 [00:00<00:00,  6.26it/s]
#                    all         20        125      0.893      0.861      0.909      0.602
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#     131/149      1.84G    0.03523    0.03831   0.005872         70        416: 100% 5/5 [00:00<00:00,  5.48it/s]
#                  Class     Images  Instances          P          R     mAP@.5 mAP@.5:.95: 100% 1/1 [00:00<00:00,  4.87it/s]
#                    all         20        125      0.893      0.862      0.904      0.604
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#     132/149      1.84G    0.03618    0.04109   0.006353         99        416: 100% 5/5 [00:00<00:00,  5.56it/s]
#                  Class     Images  Instances          P          R     mAP@.5 mAP@.5:.95: 100% 1/1 [00:00<00:00,  5.29it/s]
#                    all         20        125      0.892      0.859      0.909        0.6
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#     133/149      1.84G    0.03521     0.0357   0.005559         34        416: 100% 5/5 [00:00<00:00,  5.84it/s]
#                  Class     Images  Instances          P          R     mAP@.5 mAP@.5:.95: 100% 1/1 [00:00<00:00,  5.06it/s]
#                    all         20        125      0.896      0.857      0.904      0.598
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#     134/149      1.84G    0.03334    0.03604   0.004493         65        416: 100% 5/5 [00:00<00:00,  6.06it/s]
#                  Class     Images  Instances          P          R     mAP@.5 mAP@.5:.95: 100% 1/1 [00:00<00:00,  5.07it/s]
#                    all         20        125      0.897       0.86      0.907      0.598
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#     135/149      1.84G    0.03375    0.03344   0.004908         72        416: 100% 5/5 [00:00<00:00,  5.47it/s]
#                  Class     Images  Instances          P          R     mAP@.5 mAP@.5:.95: 100% 1/1 [00:00<00:00,  7.23it/s]
#                    all         20        125      0.897       0.86      0.917      0.609
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#     136/149      1.84G    0.03184    0.03237   0.005578         50        416: 100% 5/5 [00:00<00:00,  5.95it/s]
#                  Class     Images  Instances          P          R     mAP@.5 mAP@.5:.95: 100% 1/1 [00:00<00:00,  4.95it/s]
#                    all         20        125      0.899       0.85       0.91      0.607
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#     137/149      1.84G    0.03571     0.0391   0.005646         95        416: 100% 5/5 [00:00<00:00,  5.95it/s]
#                  Class     Images  Instances          P          R     mAP@.5 mAP@.5:.95: 100% 1/1 [00:00<00:00,  4.97it/s]
#                    all         20        125      0.899      0.851      0.905      0.603
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#     138/149      1.84G    0.03285    0.03291   0.005803         32        416: 100% 5/5 [00:00<00:00,  6.01it/s]
#                  Class     Images  Instances          P          R     mAP@.5 mAP@.5:.95: 100% 1/1 [00:00<00:00,  4.49it/s]
#                    all         20        125      0.902      0.849      0.906        0.6
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#     139/149      1.84G     0.0339    0.03625   0.005803         71        416: 100% 5/5 [00:00<00:00,  5.51it/s]
#                  Class     Images  Instances          P          R     mAP@.5 mAP@.5:.95: 100% 1/1 [00:00<00:00,  6.77it/s]
#                    all         20        125      0.896      0.861       0.91      0.598
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#     140/149      1.84G    0.03229    0.03247   0.005796         71        416: 100% 5/5 [00:00<00:00,  5.83it/s]
#                  Class     Images  Instances          P          R     mAP@.5 mAP@.5:.95: 100% 1/1 [00:00<00:00,  5.29it/s]
#                    all         20        125      0.949      0.836      0.911       0.61
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#     141/149      1.84G    0.03418    0.04183    0.00624        109        416: 100% 5/5 [00:00<00:00,  5.96it/s]
#                  Class     Images  Instances          P          R     mAP@.5 mAP@.5:.95: 100% 1/1 [00:00<00:00,  5.79it/s]
#                    all         20        125      0.949       0.83       0.91      0.604
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#     142/149      1.84G     0.0317    0.02906   0.005442         44        416: 100% 5/5 [00:00<00:00,  6.40it/s]
#                  Class     Images  Instances          P          R     mAP@.5 mAP@.5:.95: 100% 1/1 [00:00<00:00,  4.21it/s]
#                    all         20        125      0.925      0.819      0.908      0.604
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#     143/149      1.84G    0.03361    0.03644   0.007018         70        416: 100% 5/5 [00:00<00:00,  5.27it/s]
#                  Class     Images  Instances          P          R     mAP@.5 mAP@.5:.95: 100% 1/1 [00:00<00:00,  5.45it/s]
#                    all         20        125      0.925      0.832      0.907      0.606
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#     144/149      1.84G    0.03257    0.03694   0.004783         41        416: 100% 5/5 [00:00<00:00,  5.57it/s]
#                  Class     Images  Instances          P          R     mAP@.5 mAP@.5:.95: 100% 1/1 [00:00<00:00,  6.02it/s]
#                    all         20        125      0.925      0.832      0.905      0.604
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#     145/149      1.84G    0.03309     0.0339   0.006503         56        416: 100% 5/5 [00:00<00:00,  5.71it/s]
#                  Class     Images  Instances          P          R     mAP@.5 mAP@.5:.95: 100% 1/1 [00:00<00:00,  5.76it/s]
#                    all         20        125      0.922      0.832      0.904      0.597
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#     146/149      1.84G     0.0332    0.03861   0.005824        105        416: 100% 5/5 [00:00<00:00,  5.86it/s]
#                  Class     Images  Instances          P          R     mAP@.5 mAP@.5:.95: 100% 1/1 [00:00<00:00,  4.93it/s]
#                    all         20        125      0.882      0.858      0.903      0.595
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#     147/149      1.84G    0.03628    0.03628   0.006149         86        416: 100% 5/5 [00:00<00:00,  5.29it/s]
#                  Class     Images  Instances          P          R     mAP@.5 mAP@.5:.95: 100% 1/1 [00:00<00:00,  5.41it/s]
#                    all         20        125      0.879      0.857      0.903      0.602
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#     148/149      1.84G    0.03186    0.03334   0.006052         52        416: 100% 5/5 [00:00<00:00,  5.62it/s]
#                  Class     Images  Instances          P          R     mAP@.5 mAP@.5:.95: 100% 1/1 [00:00<00:00,  5.81it/s]
#                    all         20        125      0.876      0.857      0.903      0.604
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#     149/149      1.84G    0.03332    0.03225   0.005937         65        416: 100% 5/5 [00:00<00:00,  5.78it/s]
#                  Class     Images  Instances          P          R     mAP@.5 mAP@.5:.95: 100% 1/1 [00:00<00:00,  4.66it/s]
#                    all         20        125       0.88      0.857      0.903      0.601
#
# 150 epochs completed in 0.062 hours.
# Optimizer stripped from runs/train/exp2/weights/last.pt, 14.3MB
# Optimizer stripped from runs/train/exp2/weights/best.pt, 14.3MB
#
# Validating runs/train/exp2/weights/best.pt...
# Fusing layers...
# Model summary: 213 layers, 7018216 parameters, 0 gradients, 15.8 GFLOPs
#                  Class     Images  Instances          P          R     mAP@.5 mAP@.5:.95: 100% 1/1 [00:00<00:00,  3.85it/s]
#                    all         20        125      0.889      0.864      0.916      0.612
#                   head         20         18      0.832      0.825      0.897      0.591
#                 helmet         20         45      0.875      0.911      0.938      0.678
#                 person         20         62       0.96      0.855      0.911      0.568
# Results saved to runs/train/exp2

# %% [markdown]
# # Evaluate Custom YOLOv5 Detector Performance
# Training losses and performance metrics are saved to Tensorboard and also to a logfile.
#
# If you are new to these metrics, the one you want to focus on is `mAP_0.5` - learn more about mean average precision [here](https://blog.roboflow.com/mean-average-precision/).

# %%
# Start tensorboard
# Launch after you have started training
# logs save in the folder "runs"
# %load_ext tensorboard
# %tensorboard --logdir runs
# Out:
# Launching TensorBoard...

# %% [markdown]
# #Run Inference  With Trained Weights
# Run inference with a pretrained checkpoint on contents of `test/images` folder downloaded from Roboflow.

# %%
# !python detect.py --weights runs/train/exp/weights/best.pt --img 416 --conf 0.1 --source {dataset.location}/test/images

# %%
#display inference on ALL test images

import glob
from IPython.display import Image, display

for imageName in glob.glob('/content/yolov5/runs/detect/exp/*.jpg'): #assuming JPG
    display(Image(filename=imageName))
    print("\n")

# %% [markdown]
# # Conclusion and Next Steps
#
# Congratulations! You've trained a custom YOLOv5 model to recognize your custom objects.
#
# To improve you model's performance, we recommend first interating on your datasets coverage and quality. See this guide for [model performance improvement](https://github.com/ultralytics/yolov5/wiki/Tips-for-Best-Training-Results).
#
# To deploy your model to an application, see this guide on [exporting your model to deployment destinations](https://github.com/ultralytics/yolov5/issues/251).
#
# Once your model is in production, you will want to continually iterate and improve on your dataset and model via [active learning](https://blog.roboflow.com/what-is-active-learning/).

# %%
#export your model's weights for future use
from google.colab import files
files.download('./runs/train/exp/weights/best.pt')
